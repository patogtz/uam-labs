# %%
df = spark.table("workspace.sales.retail_transactions_course_dataset")

# %%
display(df)

# %%
df_clean = df
df_clean = df_clean.dropDuplicates(["transaction_id"])
df = df_clean.dropna(subset=["transaction_id", "total_eur", "transaction_ts"])

# %%
df.count()
df_clean.count()

# %%
df_clean.write.format("delta").mode("overwrite").saveAsTable("retail_delta")

# %%
# %sql
select * from retail_delta
